# %% [markdown]
# <a href="https://colab.research.google.com/github/fiapdatanalytics/datathon/blob/main/dataton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Premissas - Informações importantes para análise
#
# ## Análise – Arquivo Dicionário dados Datathon
#
# 1. A Estrutura dos Dados (Temporalidade)
#
#     O dicionário cobre um período histórico de 3 anos (2020, 2021 e 2022). Isso é crucial para as perguntas sobre evolução e para o treinamento do seu modelo preditivo (Machine Learning), pois você poderá ver o comportamento do aluno ao longo do tempo.
#
# 2. O Grande Indicador: INDE
#
#     O INDE (Índice de Desenvolvimento Educacional) é a métrica principal ("Métrica de Processo Avaliativo Geral").
#     Composição: Ele não é um número aleatório. Ele é uma ponderação de vários outros indicadores: IAN, IDA, IEG, IAA, IPS, IPP e IPV.
#     Conexão com o Desafio: A Pergunta 8 do desafio ("Multidimensionalidade") pede justamente para você descobrir quais desses sub-indicadores influenciam mais o INDE.
#
# 3. Os Sub-Indicadores
#
#     Para responder às perguntas do Desafio, você precisará dominar estas siglas definidas no dicionário:
#     •	IAN (Indicador de Adequação ao Nível): Mede se o aluno está na fase correta para a idade/conhecimento.
#     o	Uso: Responde à Pergunta 1 ("Adequação do nível").
# •	IDA (Indicador de Aprendizagem): São as notas de fato (Português, Matemática, Inglês).
# o	Uso: Responde à Pergunta 2 ("Desempenho acadêmico").
# •	IEG (Indicador de Engajamento): O quanto o aluno participa e se esforça (tarefas, presença).
# o	Uso: Responde à Pergunta 3 (Relação Engajamento x Desempenho).
# •	IAA (Autoavaliação): Como o aluno se vê.
# o	Uso: Responde à Pergunta 4 (Percepção vs. Realidade).
# •	IPS (Psicossocial) e IPP (Psicopedagógico): Avaliações de psicólogos e pedagogos.
# o	Uso: Responde às Perguntas 5 e 6 (Padrões comportamentais e emocionais).
# •	IPV (Ponto de Virada): Indicador crucial. Mostra se o aluno teve uma mudança significativa (positiva) de trajetória.
# o	Uso: Responde à Pergunta 7.
# 4. A Classificação ("Pedras")
# A Passos Mágicos classifica os alunos em "Pedras" com base no valor do INDE:
# •	Quartzo: 2.405 a 5.506
# •	Ágata: 5.506 a 6.868
# •	Ametista: 6.868 a 8.230
# •	Topázio: 8.230 a 9.294 (O nível de excelência).
# Insight: Essa categorização é perfeita para criar gráficos de funil ou evolução. Por exemplo: "Quantos alunos Quartzo em 2020 viraram Ametista em 2022?". Isso responde diretamente à Pergunta 10 sobre a "Efetividade do programa".
# 5. Dados Qualitativos e Booleanos
# O dicionário revela campos que não são notas numéricas, mas textos ou "Sim/Não":
# •	Booleanos: PONTO_VIRADA_2020, BOLSISTA_2022, INDICADO_BOLSA_2022. Estes são ótimos "rótulos" (targets) para seu modelo preditivo.
# •	Texto (Observações): DESTAQUE_IEG, DESTAQUE_IDA. Aqui tem ouro para análise de sentimento ou nuvem de palavras (Parte criativa do desafio).
# Análise – Arquivo Desvendando_Passos
# 1. O Processo de "Onboarding" (A Criação do Dado)
# O documento detalha o funil de entrada do aluno na ONG. Para sua análise de dados, isso é importante porque define o perfil inicial da sua base:
# •	Prova de Sondagem: É aqui que se mede o conhecimento técnico inicial. Isso define o ponto de partida acadêmico (que depois vira o IDA - Indicador de Aprendizagem).
# •	Entrevistas (Psico/Social/Pedagogia): Equipes multidisciplinares entrevistam família e aluno.
# o	Conexão: É daqui que nascem os primeiros registros para o IPS (Indicador Psicossocial) e IPP (Indicador Psicopedagógico).
# •	Consenso Psicopedagógico: Professores e psicólogos se reúnem para decidir a fase do aluno.
# o	Conexão: Este é o momento exato onde é definido o IAN (Indicador de Adequação ao Nível). Perceba que o IAN não é um cálculo automático, é uma decisão humana baseada em várias variáveis.
# •	Avaliação Socioeconômica: Análise de vulnerabilidade.
# o	Conexão: Isso é contexto puro para entender por que certos alunos podem ter IEG (Engajamento) mais baixo (talvez por questões familiares/financeiras, e não falta de vontade).
# 2. Insight Estratégico para o Datathon
# Ao responder às perguntas do Desafio (PDF 1), use este contexto para enriquecer seu Storytelling:
# •	Para a Pergunta 1 (Sobre o IAN): Você agora sabe que a "adequação" é decidida numa reunião de "Consenso". Se os dados mostrarem uma discrepância, você pode hipotetizar se a avaliação inicial foi precisa ou se o aluno evoluiu mais rápido que o esperado.
# •	Para a Pergunta 5 (Padrões Psicossociais): Lembre-se que a Passos Mágicos foca em "não reproduzir modelos de hierarquização social" e "garantir dignidade". Seus gráficos sobre IPS devem refletir essa humanidade, não apenas tratar o aluno como um número com "problemas".
# •	Para o Modelo Preditivo (Machine Learning): O documento cita "vulnerabilidades das famílias". Se houver dados sobre a situação familiar no dataset, eles serão features (variáveis) fortíssimas para prever o risco de evasão ou queda de desempenho.
# Resumo da Ópera: Este arquivo nos ensina que os dados da Passos Mágicos são humanizados na origem. O aluno não entra apenas com uma nota de prova; ele entra com um "diagnóstico 360º" (Social, Psicológico e Pedagógico).
# Análise – Arquivo Links adicionais da passos
# Fonte para o Storytelling
# 1. O Fator "Contexto Histórico" (Crucial para 2020/2021)
# Você tem dados de 2020 e 2021. Lembre-se: 2020 foi o ano da Pandemia.
# •	A Armadilha: Se você olhar os números de Engajamento (IEG) ou Aprendizagem (IDA) de 2020 e ver uma queda, sem ler o relatório, você dirá que "os alunos pioraram".
# •	O Insight: Lendo o relatório de 2020, você provavelmente descobrirá como a ONG lidou com o distanciamento (aulas online? cestas básicas? falta de internet?). Você usará isso para justificar oscilações nos dados. "O indicador caiu não por falta de esforço, mas devido à adaptação ao modelo remoto citada no relatório de 2020."
# 2. Validação do "Impacto Real" (Pergunta 10)
# A Pergunta 10 do desafio questiona a "Efetividade do programa" e o "impacto real".
# •	Os relatórios de 2022 e 2023 trazem os casos de sucesso, depoimentos e números consolidados de alunos que entraram na universidade.
# •	Dica: Use frases ou números macro desses relatórios para corroborar o que seu modelo preditivo ou sua análise de dados está mostrando. Se seus dados mostram evolução, o relatório confirma isso qualitativamente.
# 3. Visualização e Design
# O desafio pede uma apresentação em PPT/PDF.
# •	Não invente a roda. Abra esses relatórios para ver a identidade visual, as cores que eles usam e, principalmente, para entender a linguagem deles. Se sua apresentação "falar a língua" da Passos Mágicos (visual e textual), você ganha muitos pontos de empatia com o cliente.
# Resumo da Ópera: Estes links não são dados brutos, são argumentos de defesa. Guarde-os para o momento de escrever as conclusões da sua análise e justificar anomalias nos dados (especialmente durante a pandemia).
# Análise – Arquivo Pede_pontos importantes
# ## Arquivo mais técnico - Enquanto o Dicionário dizia "o que é", este arquivo diz "como calcula"
# 1. A "Caixa Preta" do INDE foi Aberta
# Agora sabemos que o INDE (Índice de Desenvolvimento Educacional) não é um número mágico, mas uma Média Ponderada. Isso é fundamental para responder à Pergunta 8 do desafio ("Multidimensionalidade").
# A fórmula muda drasticamente dependendo da fase do aluno:
# •	Fases 0 a 7 (Ensino Fundamental/Médio): O foco é equilibrado.
# o	IDA (20%) e IEG (20%) somam 40%.
# o	IPV (Ponto de Virada) tem um peso gigante de 20%. Ou seja, a ONG valoriza tanto a superação (IPV) quanto a nota da prova (IDA).
# •	Fase 8 (Universitários/Vestibulandos): O jogo muda.
# o	IDA sobe para 40%. O IPV e IPP deixam de existir no cálculo.
# o	Interpretação: Quando o aluno chega na porta da faculdade, o desempenho acadêmico duro torna-se o fator crítico de sucesso.
# 2. O Cálculo da Defasagem (IAN) - Resposta da Pergunta 1
# O arquivo entrega a lógica exata para a Pergunta 1 ("Adequação do Nível"):
# $$D = \text{Fase Efetiva} - \text{Fase Ideal}$$
# •	Se $D \ge 0$: Nota 10 (Está na série certa).
# •	Se a defasagem é pequena (até 2 anos): Nota 5.
# •	Se a defasagem é grande (mais de 2 anos): Nota 2,5.
# •	Dica de Análise: Você pode criar um gráfico de barras contando quantos alunos estão em cada um desses "buckets" (10, 5 ou 2,5) ao longo dos anos. Se o número de alunos com "Nota 2,5" diminuir de 2020 para 2022, o programa é um sucesso em corrigir o fluxo escolar.
# 3. A Subjetividade Quantificada (IAA)
# As imagens dos "robôs" (pictogramas) mostram como a ONG transforma sentimentos de crianças em dados numéricos.
# •	Isso é um dado categórico ordinal (A, B, C) que foi transformado em numérico.
# •	Atenção: Ao analisar o IAA, lembre-se que ele é a autoimagem do aluno. Se o IAA é alto (o aluno se acha ótimo), mas o IDA é baixo (notas ruins), existe uma dissonância cognitiva que precisa ser tratada (Pergunta 4 do desafio).
# 4. A Distribuição Normal (Curva de Gauss)
# O gráfico da "Figura 2" mostra que as notas do INDE seguem (ou deveriam seguir) uma Distribuição Normal.
# •	Média $\approx 7,1$.
# •	Pedras:
# o	Quartzo (Esquerda da curva): Alunos em risco.
# o	Ágata e Ametista (Centro): A grande massa de alunos.
# o	Topázio (Direita da curva): A elite acadêmica (High Performers).
# 5. Check de Integridade dos Dados (Dica de Ouro)
# Agora que você tem as fórmulas, uma das primeiras coisas que você deve fazer no Python/Pandas é:
# 1.	Pegar as colunas IAN, IDA, IEG, etc.
# 2.	Aplicar os pesos da tabela (0.1, 0.2, etc.).
# 3.	Verificar se o resultado bate com a coluna INDE que veio pronta na base.
# 4.	Por que fazer isso? Para encontrar erros na base de dados. Se o cálculo não bater, ou a fórmula mudou naquele ano, ou o dado está corrompido. Isso demonstra um rigor técnico de nível sênior na sua apresentação.
# ________________________________________
# ## Resumo da Ópera:
# Sabemos agora o que faz a nota de um aluno subir ou descer.
# •	Para um aluno da Fase 8 virar Topázio, ele precisa estudar (IDA).
# •	Para um aluno da Fase 2 virar Topázio, ele precisa mostrar evolução (IPV) e engajamento (IEG), não apenas nota.
# Análise – Arquivo Relatório PEDE2020
# Atenção reforçada com este ano (ano de pandemia). Se tratar os números de 2020 como números comuns, sua análise falhará.
# 1. O Contexto "Ano da Resistência" (Storytelling)
# Enquanto a educação pública no Brasil colapsou em 2020 (escolas fechadas, sem EAD), a Passos Mágicos foi na contramão.
# •	O Grande Diferencial: A ONG não parou. Eles distribuíram mais de 350 dispositivos eletrônicos e créditos de internet para garantir que os alunos continuassem conectados.
# •	Dica para Análise: Se você encontrar alunos com IEG (Engajamento) alto em 2020, isso não foi mágica; foi infraestrutura fornecida pela ONG. Verifique se existe alguma coluna na base de dados indicando "recebimento de auxílio/tablet". Se houver, cruze com o desempenho!
# 2. A Obsessão pela Matemática (Impacto no IDA)
# O relatório indica que a matemática foi identificada como o ponto crítico na pandemia.
# •	Ações Criadas: Foram lançados programas específicos como "Coração Matemático" e "Matemática Mais" em plena crise.
# •	Hipótese para Validar: Ao analisar o IDA (Indicador de Aprendizagem) de 2020 vs. 2021, veja se a nota de Matemática se sustentou melhor do que a de Português. Se sim, você prova a eficácia desses programas emergenciais (Pergunta 10 do Desafio).
# 3. Vínculo Familiar e Psicossocial (IPS)
# Em 2020, o vínculo mudou de "Aluno-Professor" para "ONG-Família".
# •	O relatório menciona o envio de relatórios quinzenais e um acompanhamento muito mais próximo das vulnerabilidades.
# •	Interpretação: O IPS (Indicador Psicossocial) de 2020 pode estar mais "sensível". Notas baixas aqui podem refletir o medo/ansiedade da pandemia, não necessariamente problemas comportamentais do aluno. Seja empático ao relatar isso.
# 4. Atenção: Não compare bananas com laranjas
# •	Erro Comum: Comparar a média de notas (IDA) de 2019 (presencial) diretamente com 2020 (remoto) sem fazer ressalvas.
# •	Correção: Ao apresentar gráficos de evolução temporal, coloque uma linha pontilhada ou uma anotação em 2020 chamando de "Periodo Pandêmico / Ensino Remoto". Isso mostra maturidade analítica.
# ________________________________________
# ## Resumo da Ópera
# O relatório de 2020 transforma seus dados frios em uma Jornada do Herói. A história que você vai contar é: "Diante do caos global, como os dados mostram que a Passos Mágicos protegeu o futuro dessas crianças?".
# Seus dados brutos (CSVs) devem ser o próximo passo. Agora que temos toda a teoria e contexto (Dicionário, Regras de Cálculo, Origem e Contexto Histórico), estamos prontos para colocar a mão no código.
# Análise – Arquivo Relatório PEDE2021
# Se 2020 foi sobre "sobrevivência", 2021 foi sobre lidar com as sequelas da pandemia e preparar o terreno para o crescimento. Para a sua análise de dados, este ano é a "ponte" entre o caos de 2020 e a estabilidade de 2022.
# 1. O Desafio do Modelo Híbrido (Contexto para o IDA)
# O relatório destaca o retorno gradual e o modelo híbrido.
# •	O que isso significa para os dados: As notas do IDA (Indicador de Aprendizagem) em 2021 podem apresentar uma variância alta. Alguns alunos se adaptaram bem ao retorno, outros demoraram.
# •	Dica de Análise: Não espere uma curva de recuperação linear perfeita. Ao modelar a evolução do IDA de 2020 para 2021, procure clusters de alunos: os que "dispararam" (recuperação rápida) e os que estagnaram. Isso responde à Pergunta 2 (Desempenho estagnado ou caindo?).
# 2. A Expansão do Programa (Volume de Dados)
# 2021 foi um ano de crescimento institucional forte para a Passos Mágicos.
# •	Impacto no Dataset: Você provavelmente notará um aumento no número de linhas (alunos) na sua base de dados de 2021 em comparação a 2020.
# •	Alerta de Viés: Cuidado ao comparar médias gerais puras de 2020 vs 2021. Novos alunos (ingressantes em 2021) entram sem o "histórico" da ONG e podem puxar a média para baixo inicialmente.
# •	Sugestão: Ao fazer gráficos de evolução, tente separar "Alunos Veteranos" (que já estavam em 2020) de "Alunos Calouros" (que entraram em 2021). O comportamento será diferente.
# 3. Foco na Saúde Mental (IPS e IPP)
# Com o retorno presencial, os problemas emocionais represados na pandemia ficaram mais visíveis.
# •	O relatório reforça a atuação da equipe de psicologia.
# •	Conexão: O IPS (Indicador Psicossocial) de 2021 é um termômetro valioso. Se você notar uma correlação forte entre IPS baixo e Queda de Desempenho (IDA) neste ano, você valida a Pergunta 5 (Padrões psicossociais que antecedem quedas). O relatório lhe dá a base teórica para afirmar que "o pós-pandemia exigiu suporte extra".
# 4. A Preparação para o Futuro (Fase 8)
# 2021 fortaleceu os programas de apadrinhamento e acesso à universidade.
# •	Isso é crucial para a Pergunta 10 (Efetividade). Se o número de alunos ingressando no ensino superior aumentou em 2021/2022, o relatório é a prova qualitativa do esforço que gerou esse número.
# ________________________________________
# ## Resumo da Ópera para o Datathon
# Ao construir seu Storytelling:
# 1.	2020: O ano da Resistência (Conectividade, Cestas Básicas).
# 2.	2021: O ano da Adaptação e Diagnóstico (Quem voltou? Como voltaram? Quem são os novos?).
# 3.	2022: (Provavelmente o próximo relatório) O ano da Consolidação.
# Esse arco narrativo dá muito mais peso à sua apresentação do que apenas mostrar "Gráfico de barras ano a ano".
# Análise – Arquivo Relatório PEDE2022
#
# Para o seu desafio de Data Analytics, 2022 é o ano mais importante por um motivo simples: é o dado mais limpo e recente que você tem. Ele representa o funcionamento "normal" e evoluído da ONG, sem o ruído extremo da pandemia de 2020 ou a transição híbrida de 2021.
# Aqui está o resumo estratégico e como ele fecha o seu Storytelling:
# 1. A "Prova Real" da Eficácia (Resposta para a Pergunta 10)
# Se as perguntas do Datathon querem saber se o programa funciona, 2022 é a resposta.
# •	Crescimento Exponencial: O relatório destaca a expansão para novos municípios e o aumento significativo no número de alunos atendidos (chegando a 1.100 alunos).
# •	Resultados Tangíveis: É o ano com recordes de ingresso em universidades e bolsas de estudo.
# •	Dica de Visualização: Use 2022 para mostrar o "Estado da Arte". Seus gráficos de barra devem mostrar uma tendência de subida que culmina nos números fortes de 2022. É o clímax da sua história de dados.
# 2. A Estabilidade para o Modelo Preditivo (Machine Learning)
# Para treinar sua inteligência artificial (Pergunta 9):
# •	Peso dos Dados: Eu recomendaria dar um peso maior aos padrões encontrados em 2022 do que aos de 2020. O comportamento de um aluno em 2020 (isolado em casa) não serve tanto para prever o risco de um aluno em 2023/2024. O comportamento de 2022 serve.
# •	Variáveis: O relatório reforça a integração das dimensões (Acadêmica + Psicossocial). Seu modelo precisa usar as colunas de IPS e IPP. O relatório prova que a Passos Mágicos não olha só para nota.
# 3. O Foco na "Trajetória de Vida" (IPV e Fase 8)
# O relatório enfatiza muito a transformação de vida (empregabilidade, universidade).
# •	Interpretação: O IPV (Índice do Ponto de Virada) ganha destaque aqui. Em 2022, esse indicador deve estar muito bem calibrado.
# •	Análise: Verifique se os alunos que tiveram alto IPV em 2020/2021 foram os que conseguiram as bolsas em 2022. Se você encontrar essa correlação, você achou um insight de ouro: "O Ponto de Virada é o melhor preditor de sucesso a longo prazo".
#
# ## Resumo estratégico:
#
#  O Cenário (Contexto): Você não está analisando números aleatórios. Você está analisando a resiliência de crianças vulneráveis através de uma pandemia (2020), uma retomada difícil (2021) e uma expansão vitoriosa (2022).
# As Regras (Dicionário/Fórmulas): Você sabe que o INDE é uma média ponderada e sabe calcular a defasagem (IAN). Use isso para validar a qualidade dos dados.
# O Objetivo (Perguntas):
# •	Provar impacto (Gráficos de evolução 2020->2022).
# •	Prever risco (Modelo treinado preferencialmente com estabilidade de 2022).
# •	Entender o aluno (Análise multidimensional IPS/IPP/IDA).

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/BASE DE DADOS PEDE 2024 - DATATHON - PEDE2022.csv')

# %%
df.head(5)
# Out:
#      RA  Fase Turma     Nome  Ano nasc  Idade 22  Gênero  Ano ingresso  \
# 0  RA-1     7     A  Aluno-1      2003        19  Menina          2016
# 1  RA-2     7     A  Aluno-2      2005        17  Menina          2017
# 2  RA-3     7     A  Aluno-3      2005        17  Menina          2016
# 3  RA-4     7     A  Aluno-4      2005        17  Menino          2017
# 4  RA-5     7     A  Aluno-5      2005        17  Menina          2016
#
#   Instituição de ensino  Pedra 20  ... Inglês Indicado Atingiu PV    IPV  \
# 0        Escola Pública  Ametista  ...    6,0      Sim        Não  7,278
# 1          Rede Decisão  Ametista  ...    9,7      Não        Não  6,778
# 2          Rede Decisão  Ametista  ...    6,9      Não        Não  7,556
# 3          Rede Decisão  Ametista  ...    8,7      Não        Não  5,278
# 4          Rede Decisão  Ametista  ...    5,7      Não        Não  7,389
#
#       IAN               Fase ideal  Defas  \
# 0   5,000  Fase 8 (Universitários)     -1
# ...

# %%
df.columns
# Out:
# Index(['RA', 'Fase', 'Turma', 'Nome', 'Ano nasc', 'Idade 22', 'Gênero',
#        'Ano ingresso', 'Instituição de ensino', 'Pedra 20', 'Pedra 21',
#        'Pedra 22', 'INDE 22', 'Cg', 'Cf', 'Ct', 'Nº Av', 'Avaliador1',
#        'Rec Av1', 'Avaliador2', 'Rec Av2', 'Avaliador3', 'Rec Av3',
#        'Avaliador4', 'Rec Av4', 'IAA', 'IEG', 'IPS', 'Rec Psicologia', 'IDA',
#        'Matem', 'Portug', 'Inglês', 'Indicado', 'Atingiu PV', 'IPV', 'IAN',
#        'Fase ideal', 'Defas', 'Destaque IEG', 'Destaque IDA', 'Destaque IPV'],
#       dtype='object')

# %%
df

# %% [markdown]
# Teste
